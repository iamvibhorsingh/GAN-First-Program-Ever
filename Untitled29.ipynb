# %%
from __future__ import print_function

from keras import backend as K
K.set_image_dim_ordering('th') # ensure our dimension notation matches

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, AveragePooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD, Adam
from keras.datasets import mnist
from keras import utils
import numpy as np
from PIL import Image, ImageOps
import argparse
import math

import os
import os.path

import glob
# Out:
# Using TensorFlow backend.

# %%
def generator_model():
    model = Sequential()
    model.add(Dense(input_dim=100, output_dim=512))
    model.add(Activation('softsign'))
    model.add(Dense(128*8*8))
    model.add(BatchNormalization())
    model.add(Activation('softsign'))
    model.add(Reshape((128, 8, 8), input_shape=(128*8*8,)))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(64, 5, 5, border_mode='same'))
    model.add(Activation('softsign'))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(1, 5, 5, border_mode='same'))
    model.add(Activation('softsign'))
    return model


def discriminator_model():
    model = Sequential()
    model.add(Convolution2D(
                        64, 5, 5,
                        border_mode='same',
                        input_shape=(1, 128, 128)))
    model.add(Activation('softsign'))
    model.add(AveragePooling2D(pool_size=(4, 4)))
    model.add(Convolution2D(128, 5, 5))
    model.add(Activation('softsign'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('softsign'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model


def generator_containing_discriminator(generator, discriminator):
    model = Sequential()
    model.add(generator)
    discriminator.trainable = False
    model.add(discriminator)
    return model


def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[2:]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[0, :, :]
    return image

# %%
model = generator_model()
print(model.summary())
# Out:
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=512, input_dim=100)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_59 (Dense)             (None, 512)               51712
# _________________________________________________________________
# activation_117 (Activation)  (None, 512)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 8192)              4202496
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 8192)              32768
# _________________________________________________________________
# activation_118 (Activation)  (None, 8192)              0
# _________________________________________________________________
# reshape_19 (Reshape)         (None, 128, 8, 8)         0
# _________________________________________________________________
# up_sampling2d_37 (UpSampling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 64, 32, 32)        204864
# _________________________________________________________________
# activation_119 (Activation)  (None, 64, 32, 32)        0
# _________________________________________________________________
# up_sampling2d_38 (UpSampling (None, 64, 128, 128)      0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 1, 128, 128)       1601
# _________________________________________________________________
# activation_120 (Activation)  (None, 1, 128, 128)       0
# =================================================================
# Total params: 4,493,441
# Trainable params: 4,477,057
# Non-trainable params: 16,384
# _________________________________________________________________
# None

# %%
def load_data(pixels=128, verbose=False):
    print("Loading data")
    X_train = []
    paths = glob.glob(os.path.normpath(os.getcwd() + '/jaffe/*.tiff'))
    for path in paths:
        if verbose: print(path)
        im = Image.open(path)
        im = ImageOps.fit(im, (pixels, pixels), Image.ANTIALIAS)
        im = ImageOps.grayscale(im)
        #im.show()
        im = np.asarray(im)
        X_train.append(im)
    print("Finished loading data")
    return np.array(X_train)

def train(epochs, BATCH_SIZE, weights=False):
    """
    :param epochs: Train for this many epochs
    :param BATCH_SIZE: Size of minibatch
    :param weights: If True, load weights from file, otherwise train the model from scratch. 
    Use this if you have already saved state of the network and want to train it further.
    """
    X_train = load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
    discriminator = discriminator_model()
    generator = generator_model()
    if weights:
        generator.load_weights('goodgenerator.h5')
        discriminator.load_weights('gooddiscriminator.h5')
    discriminator_on_generator = \
        generator_containing_discriminator(generator, discriminator)
    d_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    discriminator_on_generator.compile(
        loss='binary_crossentropy', optimizer=g_optim)
    discriminator.trainable = True
    discriminator.compile(loss='binary_crossentropy', optimizer=d_optim)
    noise = np.zeros((BATCH_SIZE, 100))
    for epoch in range(epochs):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            generated_images = generator.predict(noise, verbose=0)
            #print(generated_images.shape)
            if index % 20 == 0 and epoch % 10 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                destpath = os.path.normpath(os.getcwd()+ "/jaffe-generated-images/"+str(epoch)+"_"+str(index)+".png")
                Image.fromarray(image.astype(np.uint8)).save(destpath)
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = discriminator.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            discriminator.trainable = False
            g_loss = discriminator_on_generator.train_on_batch(
                noise, [1] * BATCH_SIZE)
            discriminator.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if epoch % 10 == 9:
                generator.save_weights('goodgenerator.h5', True)
                discriminator.save_weights('gooddiscriminator.h5', True)

def clean(image):
    for i in range(1, image.shape[0] - 1):
        for j in range(1, image.shape[1] - 1):
            if image[i][j] + image[i+1][j] + image[i][j+1] + image[i-1][j] + image[i][j-1] > 127 * 5:
                image[i][j] = 255
    return image
def generate(BATCH_SIZE):
    generator = generator_model()
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    generator.load_weights('goodgenerator.h5')
    noise = np.zeros((BATCH_SIZE, 100))
    a = np.random.uniform(-1, 1, 100)
    b = np.random.uniform(-1, 1, 100)
    grad = (b - a) / BATCH_SIZE
    for i in range(BATCH_SIZE):
        noise[i, :] = np.random.uniform(-1, 1, 100)
    generated_images = generator.predict(noise, verbose=1)
    #image = combine_images(generated_images)
    print(generated_images.shape)
    for image in generated_images:
        image = image[0]
        image = image*127.5+127.5
        Image.fromarray(image.astype(np.uint8)).save("dirty.png")
        Image.fromarray(image.astype(np.uint8)).show()
        clean(image)
        image = Image.fromarray(image.astype(np.uint8))
        image.show()        
        image.save("clean.png")


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--mode", type=str)
    parser.add_argument("--batch_size", type=int, default=128)
    parser.add_argument("--nice", dest="nice", action="store_true")
    parser.set_defaults(nice=False)
    args = parser.parse_args()
    return args

# %%
train(40,10,False)
# Out:
# Loading data
# Finished loading data
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), input_shape=(1, 128, 1..., padding="same")`
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (5, 5))`
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=512, input_dim=100)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# Epoch is 0
# Number of batches 21
# batch 0 d_loss : 0.685145
# batch 0 g_loss : 0.690927
# batch 1 d_loss : 0.674899
# batch 1 g_loss : 0.693193
# batch 2 d_loss : 0.674612
# batch 2 g_loss : 0.691920
# batch 3 d_loss : 0.673626
# batch 3 g_loss : 0.696336
# batch 4 d_loss : 0.647582
# batch 4 g_loss : 0.697387
# batch 5 d_loss : 0.629557
# batch 5 g_loss : 0.700939
# batch 6 d_loss : 0.617320
# batch 6 g_loss : 0.695952
# batch 7 d_loss : 0.625635
# batch 7 g_loss : 0.698420
# batch 8 d_loss : 0.616364
# batch 8 g_loss : 0.695661
# batch 9 d_loss : 0.594169
# batch 9 g_loss : 0.711157
# batch 10 d_loss : 0.574421
# batch 10 g_loss : 0.700526
# batch 11 d_loss : 0.562472
# batch 11 g_loss : 0.703684
# batch 12 d_loss : 0.545179
# batch 12 g_loss : 0.709139
# batch 13 d_loss : 0.537994
# batch 13 g_loss : 0.713015
# batch 14 d_loss : 0.524559
# batch 14 g_loss : 0.715892
# batch 15 d_loss : 0.503633
# batch 15 g_loss : 0.707399
# batch 16 d_loss : 0.490070
# batch 16 g_loss : 0.710030
# batch 17 d_loss : 0.482451
# batch 17 g_loss : 0.708531
# batch 18 d_loss : 0.471554
# batch 18 g_loss : 0.725147
# batch 19 d_loss : 0.469961
# batch 19 g_loss : 0.710571
# batch 20 d_loss : 0.462235
# batch 20 g_loss : 0.718666
# Epoch is 1
# Number of batches 21
# batch 0 d_loss : 0.450053
# batch 0 g_loss : 0.714596
# batch 1 d_loss : 0.450877
# batch 1 g_loss : 0.710133
# batch 2 d_loss : 0.439281
# batch 2 g_loss : 0.722885
# batch 3 d_loss : 0.440876
# batch 3 g_loss : 0.726341
# batch 4 d_loss : 0.422540
# batch 4 g_loss : 0.719347
# batch 5 d_loss : 0.409949
# batch 5 g_loss : 0.729387
# batch 6 d_loss : 0.427173
# batch 6 g_loss : 0.734692
# batch 7 d_loss : 0.489904
# batch 7 g_loss : 0.720604
# batch 8 d_loss : 0.475023
# batch 8 g_loss : 0.741499
# batch 9 d_loss : 0.409190
# batch 9 g_loss : 0.737473
# batch 10 d_loss : 0.414116
# batch 10 g_loss : 0.751457
# batch 11 d_loss : 0.397535
# batch 11 g_loss : 0.741309
# batch 12 d_loss : 0.417374
# batch 12 g_loss : 0.737959
# batch 13 d_loss : 0.422211
# batch 13 g_loss : 0.745640
# batch 14 d_loss : 0.413058
# batch 14 g_loss : 0.763894
# batch 15 d_loss : 0.392601
# batch 15 g_loss : 0.768729
# batch 16 d_loss : 0.396662
# batch 16 g_loss : 0.774621
# batch 17 d_loss : 0.413172
# batch 17 g_loss : 0.767361
# batch 18 d_loss : 0.392708
# batch 18 g_loss : 0.776348
# batch 19 d_loss : 0.390786
# batch 19 g_loss : 0.756220
# batch 20 d_loss : 0.371837
# batch 20 g_loss : 0.777901
# Epoch is 2
# Number of batches 21
# batch 0 d_loss : 0.385837
# batch 0 g_loss : 0.782273
# batch 1 d_loss : 0.391812
# batch 1 g_loss : 0.810941
# batch 2 d_loss : 0.378771
# batch 2 g_loss : 0.802248
# batch 3 d_loss : 0.360154
# batch 3 g_loss : 0.824929
# batch 4 d_loss : 0.355922
# batch 4 g_loss : 0.832415
# batch 5 d_loss : 0.343486
# batch 5 g_loss : 0.818542
# batch 6 d_loss : 0.350610
# batch 6 g_loss : 0.843555
# batch 7 d_loss : 0.377742
# batch 7 g_loss : 0.842427
# batch 8 d_loss : 0.377547
# batch 8 g_loss : 0.874544
# batch 9 d_loss : 0.331817
# batch 9 g_loss : 0.905280
# batch 10 d_loss : 0.327255
# batch 10 g_loss : 0.920562
# batch 11 d_loss : 0.324516
# batch 11 g_loss : 0.932525
# batch 12 d_loss : 0.306658
# batch 12 g_loss : 0.930248
# batch 13 d_loss : 0.295413
# batch 13 g_loss : 0.966530
# batch 14 d_loss : 0.274464
# batch 14 g_loss : 1.000676
# batch 15 d_loss : 0.275996
# batch 15 g_loss : 1.022221
# batch 16 d_loss : 0.260684
# batch 16 g_loss : 1.030812
# batch 17 d_loss : 0.277368
# batch 17 g_loss : 1.053631
# batch 18 d_loss : 0.257429
# batch 18 g_loss : 1.116768
# batch 19 d_loss : 0.235078
# batch 19 g_loss : 1.104647
# batch 20 d_loss : 0.225830
# batch 20 g_loss : 1.124877
# Epoch is 3
# Number of batches 21
# batch 0 d_loss : 0.248388
# batch 0 g_loss : 1.117590
# batch 1 d_loss : 0.215598
# batch 1 g_loss : 1.174941
# batch 2 d_loss : 0.222041
# batch 2 g_loss : 1.193046
# batch 3 d_loss : 0.212750
# batch 3 g_loss : 1.181894
# batch 4 d_loss : 0.190798
# batch 4 g_loss : 1.228366
# batch 5 d_loss : 0.173722
# batch 5 g_loss : 1.225104
# batch 6 d_loss : 0.187388
# batch 6 g_loss : 1.250611
# batch 7 d_loss : 0.197547
# batch 7 g_loss : 1.275697
# batch 8 d_loss : 0.199061
# batch 8 g_loss : 1.295935
# batch 9 d_loss : 0.200912
# batch 9 g_loss : 1.315533
# batch 10 d_loss : 0.204981
# batch 10 g_loss : 1.302069
# batch 11 d_loss : 0.215196
# batch 11 g_loss : 1.342584
# batch 12 d_loss : 0.183049
# batch 12 g_loss : 1.361132
# batch 13 d_loss : 0.165461
# batch 13 g_loss : 1.355336
# batch 14 d_loss : 0.159016
# batch 14 g_loss : 1.350075
# batch 15 d_loss : 0.182642
# batch 15 g_loss : 1.339701
# batch 16 d_loss : 0.176413
# batch 16 g_loss : 1.311326
# batch 17 d_loss : 0.204570
# batch 17 g_loss : 1.329868
# batch 18 d_loss : 0.193606
# batch 18 g_loss : 1.337215
# batch 19 d_loss : 0.180644
# batch 19 g_loss : 1.264700
# batch 20 d_loss : 0.180808
# batch 20 g_loss : 1.318318
# Epoch is 4
# Number of batches 21
# batch 0 d_loss : 0.231970
# batch 0 g_loss : 1.307306
# batch 1 d_loss : 0.184273
# batch 1 g_loss : 1.271215
# batch 2 d_loss : 0.224735
# batch 2 g_loss : 1.286969
# batch 3 d_loss : 0.226920
# batch 3 g_loss : 1.269411
# batch 4 d_loss : 0.226429
# batch 4 g_loss : 1.250951
# batch 5 d_loss : 0.221981
# batch 5 g_loss : 1.217032
# batch 6 d_loss : 0.233232
# batch 6 g_loss : 1.206601
# batch 7 d_loss : 0.258633
# batch 7 g_loss : 1.238610
# batch 8 d_loss : 0.275100
# batch 8 g_loss : 1.195216
# batch 9 d_loss : 0.316839
# batch 9 g_loss : 1.220357
# batch 10 d_loss : 0.311555
# batch 10 g_loss : 1.180004
# batch 11 d_loss : 0.313805
# batch 11 g_loss : 1.210418
# batch 12 d_loss : 0.274641
# batch 12 g_loss : 1.296546
# batch 13 d_loss : 0.251422
# batch 13 g_loss : 1.341129
# batch 14 d_loss : 0.216888
# batch 14 g_loss : 1.378948
# batch 15 d_loss : 0.234150
# batch 15 g_loss : 1.467308
# batch 16 d_loss : 0.200318
# batch 16 g_loss : 1.416725
# batch 17 d_loss : 0.198592
# batch 17 g_loss : 1.551431
# batch 18 d_loss : 0.177152
# batch 18 g_loss : 1.651046
# batch 19 d_loss : 0.139865
# batch 19 g_loss : 1.794177
# batch 20 d_loss : 0.120462
# batch 20 g_loss : 1.780733
# Epoch is 5
# Number of batches 21
# batch 0 d_loss : 0.122949
# batch 0 g_loss : 2.062107
# batch 1 d_loss : 0.104927
# batch 1 g_loss : 2.057593
# batch 2 d_loss : 0.091397
# batch 2 g_loss : 2.240017
# batch 3 d_loss : 0.075531
# batch 3 g_loss : 2.219307
# batch 4 d_loss : 0.064951
# batch 4 g_loss : 2.390485
# batch 5 d_loss : 0.054069
# batch 5 g_loss : 2.487645
# batch 6 d_loss : 0.061086
# batch 6 g_loss : 2.503848
# batch 7 d_loss : 0.113873
# batch 7 g_loss : 2.658283
# batch 8 d_loss : 0.101182
# batch 8 g_loss : 2.702180
# batch 9 d_loss : 0.050356
# batch 9 g_loss : 2.752527
# batch 10 d_loss : 0.042535
# batch 10 g_loss : 2.803947
# batch 11 d_loss : 0.040695
# batch 11 g_loss : 2.730635
# batch 12 d_loss : 0.037640
# batch 12 g_loss : 2.729247
# batch 13 d_loss : 0.045324
# batch 13 g_loss : 2.775526
# batch 14 d_loss : 0.037706
# batch 14 g_loss : 2.844320
# batch 15 d_loss : 0.029077
# batch 15 g_loss : 2.886651
# batch 16 d_loss : 0.028061
# batch 16 g_loss : 2.843381
# batch 17 d_loss : 0.029939
# batch 17 g_loss : 2.892099
# batch 18 d_loss : 0.026414
# batch 18 g_loss : 2.871030
# batch 19 d_loss : 0.025818
# batch 19 g_loss : 2.845668
# batch 20 d_loss : 0.026058
# batch 20 g_loss : 2.849650
# Epoch is 6
# Number of batches 21
# batch 0 d_loss : 0.030197
# batch 0 g_loss : 2.771350
# batch 1 d_loss : 0.041300
# batch 1 g_loss : 2.774012
# batch 2 d_loss : 0.034070
# batch 2 g_loss : 2.777529
# batch 3 d_loss : 0.035774
# batch 3 g_loss : 2.694105
# batch 4 d_loss : 0.034815
# batch 4 g_loss : 2.618875
# batch 5 d_loss : 0.042500
# batch 5 g_loss : 2.518532
# batch 6 d_loss : 0.057557
# batch 6 g_loss : 2.629612
# batch 7 d_loss : 0.133284
# batch 7 g_loss : 2.438177
# batch 8 d_loss : 0.138120
# batch 8 g_loss : 2.273933
# batch 9 d_loss : 0.081090
# batch 9 g_loss : 2.276494
# batch 10 d_loss : 0.079779
# batch 10 g_loss : 2.190721
# batch 11 d_loss : 0.091363
# batch 11 g_loss : 2.177444
# batch 12 d_loss : 0.191260
# batch 12 g_loss : 2.002536
# batch 13 d_loss : 0.206753
# batch 13 g_loss : 2.172058
# batch 14 d_loss : 0.235458
# batch 14 g_loss : 1.972370
# batch 15 d_loss : 0.195354
# batch 15 g_loss : 2.004413
# batch 16 d_loss : 0.228020
# batch 16 g_loss : 1.973982
# batch 17 d_loss : 0.263839
# batch 17 g_loss : 1.886731
# batch 18 d_loss : 0.290317
# batch 18 g_loss : 1.982422
# batch 19 d_loss : 0.245273
# batch 19 g_loss : 2.207476
# batch 20 d_loss : 0.223886
# batch 20 g_loss : 2.117771
# Epoch is 7
# Number of batches 21
# batch 0 d_loss : 0.185068
# batch 0 g_loss : 2.309047
# batch 1 d_loss : 0.169732
# batch 1 g_loss : 2.447002
# batch 2 d_loss : 0.163334
# batch 2 g_loss : 2.447170
# batch 3 d_loss : 0.135968
# batch 3 g_loss : 2.573383
# batch 4 d_loss : 0.101697
# batch 4 g_loss : 2.770319
# batch 5 d_loss : 0.085295
# batch 5 g_loss : 2.845725
# batch 6 d_loss : 0.112030
# batch 6 g_loss : 2.852346
# batch 7 d_loss : 0.262572
# batch 7 g_loss : 3.196014
# batch 8 d_loss : 0.227890
# batch 8 g_loss : 3.249223
# batch 9 d_loss : 0.125260
# batch 9 g_loss : 3.223820
# batch 10 d_loss : 0.115015
# batch 10 g_loss : 3.256944
# batch 11 d_loss : 0.117754
# batch 11 g_loss : 3.465155
# batch 12 d_loss : 0.100023
# batch 12 g_loss : 3.388020
# batch 13 d_loss : 0.090388
# batch 13 g_loss : 3.219933
# batch 14 d_loss : 0.060092
# batch 14 g_loss : 3.352074
# batch 15 d_loss : 0.066594
# batch 15 g_loss : 3.486783
# batch 16 d_loss : 0.063537
# batch 16 g_loss : 3.449914
# batch 17 d_loss : 0.098069
# batch 17 g_loss : 3.280754
# batch 18 d_loss : 0.069415
# batch 18 g_loss : 3.432607
# batch 19 d_loss : 0.042505
# batch 19 g_loss : 3.438237
# batch 20 d_loss : 0.037244
# batch 20 g_loss : 3.227122
# Epoch is 8
# Number of batches 21
# batch 0 d_loss : 0.077667
# batch 0 g_loss : 3.199013
# batch 1 d_loss : 0.045319
# batch 1 g_loss : 3.356815
# batch 2 d_loss : 0.053163
# batch 2 g_loss : 3.186797
# batch 3 d_loss : 0.047247
# batch 3 g_loss : 3.096673
# batch 4 d_loss : 0.033830
# batch 4 g_loss : 2.928369
# batch 5 d_loss : 0.026001
# batch 5 g_loss : 3.130355
# batch 6 d_loss : 0.040556
# batch 6 g_loss : 3.198561
# batch 7 d_loss : 0.059031
# batch 7 g_loss : 3.152385
# batch 8 d_loss : 0.059944
# batch 8 g_loss : 2.944374
# batch 9 d_loss : 0.050078
# batch 9 g_loss : 3.041752
# batch 10 d_loss : 0.045950
# batch 10 g_loss : 3.070237
# batch 11 d_loss : 0.046815
# batch 11 g_loss : 2.823171
# batch 12 d_loss : 0.041898
# batch 12 g_loss : 3.051241
# batch 13 d_loss : 0.036239
# batch 13 g_loss : 2.936418
# batch 14 d_loss : 0.026117
# batch 14 g_loss : 2.945101
# batch 15 d_loss : 0.034551
# batch 15 g_loss : 2.659485
# batch 16 d_loss : 0.032135
# batch 16 g_loss : 2.881650
# batch 17 d_loss : 0.044446
# batch 17 g_loss : 2.907824
# batch 18 d_loss : 0.041771
# batch 18 g_loss : 2.890297
# batch 19 d_loss : 0.030479
# batch 19 g_loss : 2.788673
# batch 20 d_loss : 0.037205
# batch 20 g_loss : 2.815225
# Epoch is 9
# Number of batches 21
# batch 0 d_loss : 0.043989
# batch 0 g_loss : 2.665094
# batch 1 d_loss : 0.048300
# batch 1 g_loss : 2.788478
# batch 2 d_loss : 0.037372
# batch 2 g_loss : 2.616462
# batch 3 d_loss : 0.038478
# batch 3 g_loss : 2.669261
# batch 4 d_loss : 0.035865
# batch 4 g_loss : 2.595132
# batch 5 d_loss : 0.033884
# batch 5 g_loss : 2.770480
# batch 6 d_loss : 0.047110
# batch 6 g_loss : 2.468136
# batch 7 d_loss : 0.052051
# batch 7 g_loss : 2.763805
# batch 8 d_loss : 0.044448
# batch 8 g_loss : 2.615925
# batch 9 d_loss : 0.048071
# batch 9 g_loss : 2.780572
# batch 10 d_loss : 0.074772
# batch 10 g_loss : 2.645687
# batch 11 d_loss : 0.058679
# batch 11 g_loss : 2.815673
# batch 12 d_loss : 0.054835
# batch 12 g_loss : 2.648819
# batch 13 d_loss : 0.044320
# batch 13 g_loss : 2.891814
# batch 14 d_loss : 0.080535
# batch 14 g_loss : 2.384450
# batch 15 d_loss : 0.048612
# batch 15 g_loss : 2.596192
# batch 16 d_loss : 0.046750
# batch 16 g_loss : 2.731998
# batch 17 d_loss : 0.115776
# batch 17 g_loss : 2.731616
# batch 18 d_loss : 0.071125
# batch 18 g_loss : 2.807229
# batch 19 d_loss : 0.076095
# batch 19 g_loss : 2.742752
# batch 20 d_loss : 0.055013
# batch 20 g_loss : 2.504287
# Epoch is 10
# Number of batches 21
# batch 0 d_loss : 0.111386
# batch 0 g_loss : 2.617751
# batch 1 d_loss : 0.074290
# batch 1 g_loss : 3.028167
# batch 2 d_loss : 0.107753
# batch 2 g_loss : 2.718989
# batch 3 d_loss : 0.113114
# batch 3 g_loss : 2.765862
# batch 4 d_loss : 0.118671
# batch 4 g_loss : 3.137767
# batch 5 d_loss : 0.043933
# batch 5 g_loss : 2.632429
# batch 6 d_loss : 0.138644
# batch 6 g_loss : 2.706697
# batch 7 d_loss : 0.204339
# batch 7 g_loss : 2.871700
# batch 8 d_loss : 0.179682
# batch 8 g_loss : 2.839472
# batch 9 d_loss : 0.205716
# batch 9 g_loss : 3.024338
# batch 10 d_loss : 0.243304
# batch 10 g_loss : 2.877221
# batch 11 d_loss : 0.389310
# batch 11 g_loss : 3.198255
# batch 12 d_loss : 0.206139
# batch 12 g_loss : 2.649255
# batch 13 d_loss : 0.197185
# batch 13 g_loss : 2.898028
# batch 14 d_loss : 0.197475
# batch 14 g_loss : 2.729388
# batch 15 d_loss : 0.324867
# batch 15 g_loss : 2.982698
# batch 16 d_loss : 0.352872
# batch 16 g_loss : 3.095990
# batch 17 d_loss : 0.778520
# batch 17 g_loss : 3.175478
# batch 18 d_loss : 0.661738
# batch 18 g_loss : 2.933772
# batch 19 d_loss : 0.523133
# batch 19 g_loss : 3.118425
# batch 20 d_loss : 0.436419
# batch 20 g_loss : 3.175364
# Epoch is 11
# Number of batches 21
# batch 0 d_loss : 0.885085
# batch 0 g_loss : 3.148274
# batch 1 d_loss : 0.452831
# batch 1 g_loss : 3.360522
# batch 2 d_loss : 0.688097
# batch 2 g_loss : 3.479986
# batch 3 d_loss : 0.613091
# batch 3 g_loss : 3.733503
# batch 4 d_loss : 0.537681
# batch 4 g_loss : 3.554310
# batch 5 d_loss : 0.414874
# batch 5 g_loss : 3.752895
# batch 6 d_loss : 0.380457
# batch 6 g_loss : 3.514953
# batch 7 d_loss : 0.428141
# batch 7 g_loss : 3.750304
# batch 8 d_loss : 0.444435
# batch 8 g_loss : 3.870816
# batch 9 d_loss : 0.490682
# batch 9 g_loss : 3.978188
# batch 10 d_loss : 0.404004
# batch 10 g_loss : 3.706684
# batch 11 d_loss : 0.324221
# batch 11 g_loss : 4.030608
# batch 12 d_loss : 0.256693
# batch 12 g_loss : 4.040288
# batch 13 d_loss : 0.253233
# batch 13 g_loss : 3.860760
# batch 14 d_loss : 0.168803
# batch 14 g_loss : 4.033380
# batch 15 d_loss : 0.134743
# batch 15 g_loss : 4.113509
# batch 16 d_loss : 0.141208
# batch 16 g_loss : 3.778742
# batch 17 d_loss : 0.137668
# batch 17 g_loss : 4.148850
# batch 18 d_loss : 0.127596
# batch 18 g_loss : 4.149750
# batch 19 d_loss : 0.113981
# batch 19 g_loss : 4.065051
# batch 20 d_loss : 0.102859
# batch 20 g_loss : 4.008506
# Epoch is 12
# Number of batches 21
# batch 0 d_loss : 0.129094
# batch 0 g_loss : 4.038519
# batch 1 d_loss : 0.184556
# batch 1 g_loss : 3.996808
# batch 2 d_loss : 0.170740
# batch 2 g_loss : 4.179082
# batch 3 d_loss : 0.130441
# batch 3 g_loss : 4.156796
# batch 4 d_loss : 0.146846
# batch 4 g_loss : 4.144548
# batch 5 d_loss : 0.164121
# batch 5 g_loss : 4.225717
# batch 6 d_loss : 0.269537
# batch 6 g_loss : 3.784691
# batch 7 d_loss : 1.033821
# batch 7 g_loss : 3.798855
# batch 8 d_loss : 0.886445
# batch 8 g_loss : 3.933324
# batch 9 d_loss : 0.317420
# batch 9 g_loss : 3.820501
# batch 10 d_loss : 0.312936
# batch 10 g_loss : 3.960628
# batch 11 d_loss : 0.350231
# batch 11 g_loss : 3.551991
# batch 12 d_loss : 0.408263
# batch 12 g_loss : 4.150903
# batch 13 d_loss : 0.729738
# batch 13 g_loss : 3.919101
# batch 14 d_loss : 0.503620
# batch 14 g_loss : 4.195125
# batch 15 d_loss : 0.236619
# batch 15 g_loss : 3.803813
# batch 16 d_loss : 0.313374
# batch 16 g_loss : 4.152466
# batch 17 d_loss : 0.371053
# batch 17 g_loss : 4.429949
# batch 18 d_loss : 0.332324
# batch 18 g_loss : 4.366242
# batch 19 d_loss : 0.338795
# batch 19 g_loss : 4.662592
# batch 20 d_loss : 0.259751
# batch 20 g_loss : 4.191262
# Epoch is 13
# Number of batches 21
# batch 0 d_loss : 0.493319
# batch 0 g_loss : 4.147810
# batch 1 d_loss : 0.543861
# batch 1 g_loss : 3.997686
# batch 2 d_loss : 0.427736
# batch 2 g_loss : 4.179355
# batch 3 d_loss : 0.334148
# batch 3 g_loss : 3.808686
# batch 4 d_loss : 0.200476
# batch 4 g_loss : 3.845187
# batch 5 d_loss : 0.284755
# batch 5 g_loss : 3.735616
# batch 6 d_loss : 0.288003
# batch 6 g_loss : 3.596411
# batch 7 d_loss : 0.626097
# batch 7 g_loss : 3.921646
# batch 8 d_loss : 0.468484
# batch 8 g_loss : 3.203808
# batch 9 d_loss : 0.221621
# batch 9 g_loss : 3.591753
# batch 10 d_loss : 0.175815
# batch 10 g_loss : 3.147585
# batch 11 d_loss : 0.194026
# batch 11 g_loss : 3.322877
# batch 12 d_loss : 0.114583
# batch 12 g_loss : 3.620738
# batch 13 d_loss : 0.188614
# batch 13 g_loss : 3.493989
# batch 14 d_loss : 0.100323
# batch 14 g_loss : 3.270588
# batch 15 d_loss : 0.055569
# batch 15 g_loss : 3.293420
# batch 16 d_loss : 0.047306
# batch 16 g_loss : 2.892043
# batch 17 d_loss : 0.127381
# batch 17 g_loss : 3.291953
# batch 18 d_loss : 0.081751
# batch 18 g_loss : 3.295120
# batch 19 d_loss : 0.048344
# batch 19 g_loss : 3.321343
# batch 20 d_loss : 0.033249
# batch 20 g_loss : 2.988988
# Epoch is 14
# Number of batches 21
# batch 0 d_loss : 0.076490
# batch 0 g_loss : 3.187182
# batch 1 d_loss : 0.035732
# batch 1 g_loss : 3.287902
# batch 2 d_loss : 0.097391
# batch 2 g_loss : 3.336134
# batch 3 d_loss : 0.077410
# batch 3 g_loss : 2.845224
# batch 4 d_loss : 0.058875
# batch 4 g_loss : 3.254871
# batch 5 d_loss : 0.026335
# batch 5 g_loss : 3.023158
# batch 6 d_loss : 0.043325
# batch 6 g_loss : 3.066665
# batch 7 d_loss : 0.045399
# batch 7 g_loss : 2.876821
# batch 8 d_loss : 0.069618
# batch 8 g_loss : 3.345383
# batch 9 d_loss : 0.065584
# batch 9 g_loss : 3.200198
# batch 10 d_loss : 0.067961
# batch 10 g_loss : 3.108772
# batch 11 d_loss : 0.071993
# batch 11 g_loss : 2.971527
# batch 12 d_loss : 0.055393
# batch 12 g_loss : 2.944953
# batch 13 d_loss : 0.041920
# batch 13 g_loss : 3.105916
# batch 14 d_loss : 0.039301
# batch 14 g_loss : 3.190125
# batch 15 d_loss : 0.034472
# batch 15 g_loss : 2.489513
# batch 16 d_loss : 0.035991
# batch 16 g_loss : 2.847138
# batch 17 d_loss : 0.097699
# batch 17 g_loss : 3.108871
# batch 18 d_loss : 0.061417
# batch 18 g_loss : 2.970307
# batch 19 d_loss : 0.029285
# batch 19 g_loss : 3.339906
# batch 20 d_loss : 0.023535
# batch 20 g_loss : 2.978132
# Epoch is 15
# Number of batches 21
# batch 0 d_loss : 0.066378
# batch 0 g_loss : 2.713145
# batch 1 d_loss : 0.051719
# batch 1 g_loss : 3.025420
# batch 2 d_loss : 0.069604
# batch 2 g_loss : 2.833320
# batch 3 d_loss : 0.079663
# batch 3 g_loss : 3.112844
# batch 4 d_loss : 0.094329
# batch 4 g_loss : 2.627718
# batch 5 d_loss : 0.106243
# batch 5 g_loss : 3.142876
# batch 6 d_loss : 0.076380
# batch 6 g_loss : 2.676998
# batch 7 d_loss : 0.078168
# batch 7 g_loss : 3.159524
# batch 8 d_loss : 0.037503
# batch 8 g_loss : 2.653516
# batch 9 d_loss : 0.114679
# batch 9 g_loss : 3.435806
# batch 10 d_loss : 0.112076
# batch 10 g_loss : 3.504173
# batch 11 d_loss : 0.141863
# batch 11 g_loss : 2.897037
# batch 12 d_loss : 0.084896
# batch 12 g_loss : 2.686277
# batch 13 d_loss : 0.129978
# batch 13 g_loss : 2.877431
# batch 14 d_loss : 0.148653
# batch 14 g_loss : 3.203830
# batch 15 d_loss : 0.091437
# batch 15 g_loss : 3.076703
# batch 16 d_loss : 0.151406
# batch 16 g_loss : 3.029342
# batch 17 d_loss : 0.200177
# batch 17 g_loss : 2.627003
# batch 18 d_loss : 0.147679
# batch 18 g_loss : 3.199469
# batch 19 d_loss : 0.077836
# batch 19 g_loss : 2.818036
# batch 20 d_loss : 0.114627
# batch 20 g_loss : 2.968423
# Epoch is 16
# Number of batches 21
# batch 0 d_loss : 0.272249
# batch 0 g_loss : 3.044348
# batch 1 d_loss : 0.195057
# batch 1 g_loss : 3.004081
# batch 2 d_loss : 0.362143
# batch 2 g_loss : 2.896190
# batch 3 d_loss : 0.268467
# batch 3 g_loss : 3.023682
# batch 4 d_loss : 0.179734
# batch 4 g_loss : 3.151224
# batch 5 d_loss : 0.083353
# batch 5 g_loss : 3.520072
# batch 6 d_loss : 0.127899
# batch 6 g_loss : 2.890236
# batch 7 d_loss : 0.108415
# batch 7 g_loss : 2.919080
# batch 8 d_loss : 0.108996
# batch 8 g_loss : 3.019845
# batch 9 d_loss : 0.280509
# batch 9 g_loss : 3.223686
# batch 10 d_loss : 0.383414
# batch 10 g_loss : 2.773137
# batch 11 d_loss : 0.650535
# batch 11 g_loss : 2.963413
# batch 12 d_loss : 0.293363
# batch 12 g_loss : 2.821168
# batch 13 d_loss : 0.252089
# batch 13 g_loss : 2.779626
# batch 14 d_loss : 0.186554
# batch 14 g_loss : 2.734430
# batch 15 d_loss : 0.206611
# batch 15 g_loss : 2.967833
# batch 16 d_loss : 0.378583
# batch 16 g_loss : 3.125676
# batch 17 d_loss : 0.567142
# batch 17 g_loss : 2.809783
# batch 18 d_loss : 0.342171
# batch 18 g_loss : 3.076875
# batch 19 d_loss : 0.440177
# batch 19 g_loss : 2.643011
# batch 20 d_loss : 0.459623
# batch 20 g_loss : 2.548779
# Epoch is 17
# Number of batches 21
# batch 0 d_loss : 0.493536
# batch 0 g_loss : 3.076252
# batch 1 d_loss : 0.450121
# batch 1 g_loss : 2.826147
# batch 2 d_loss : 0.924608
# batch 2 g_loss : 2.769432
# batch 3 d_loss : 0.874489
# batch 3 g_loss : 3.021981
# batch 4 d_loss : 0.593736
# batch 4 g_loss : 2.266171
# batch 5 d_loss : 0.212543
# batch 5 g_loss : 3.289227
# batch 6 d_loss : 0.248143
# batch 6 g_loss : 3.081700
# batch 7 d_loss : 0.360442
# batch 7 g_loss : 2.994321
# batch 8 d_loss : 0.367665
# batch 8 g_loss : 2.494862
# batch 9 d_loss : 0.636970
# batch 9 g_loss : 3.229619
# batch 10 d_loss : 0.670551
# batch 10 g_loss : 2.744565
# batch 11 d_loss : 0.884443
# batch 11 g_loss : 2.450191
# batch 12 d_loss : 0.503257
# batch 12 g_loss : 2.588738
# batch 13 d_loss : 0.356044
# batch 13 g_loss : 2.705030
# batch 14 d_loss : 0.260573
# batch 14 g_loss : 3.005377
# batch 15 d_loss : 0.287390
# batch 15 g_loss : 3.003735
# batch 16 d_loss : 0.432912
# batch 16 g_loss : 3.151902
# batch 17 d_loss : 0.549351
# batch 17 g_loss : 2.940128
# batch 18 d_loss : 0.353786
# batch 18 g_loss : 2.840894
# batch 19 d_loss : 0.224827
# batch 19 g_loss : 2.936770
# batch 20 d_loss : 0.250740
# batch 20 g_loss : 3.049307
# Epoch is 18
# Number of batches 21
# batch 0 d_loss : 0.480820
# batch 0 g_loss : 3.634860
# batch 1 d_loss : 0.173298
# batch 1 g_loss : 3.225119
# batch 2 d_loss : 0.468734
# batch 2 g_loss : 2.900914
# batch 3 d_loss : 0.491748
# batch 3 g_loss : 2.701994
# batch 4 d_loss : 0.260841
# batch 4 g_loss : 3.135204
# batch 5 d_loss : 0.202281
# batch 5 g_loss : 2.841097
# batch 6 d_loss : 0.245412
# batch 6 g_loss : 3.391317
# batch 7 d_loss : 0.332866
# batch 7 g_loss : 3.392456
# batch 8 d_loss : 0.303482
# batch 8 g_loss : 3.259041
# batch 9 d_loss : 0.219543
# batch 9 g_loss : 2.665385
# batch 10 d_loss : 0.247425
# batch 10 g_loss : 2.957679
# batch 11 d_loss : 0.288246
# batch 11 g_loss : 2.903784
# batch 12 d_loss : 0.257821
# batch 12 g_loss : 3.014074
# batch 13 d_loss : 0.283136
# batch 13 g_loss : 2.965280
# batch 14 d_loss : 0.177985
# batch 14 g_loss : 2.810398
# batch 15 d_loss : 0.165491
# batch 15 g_loss : 3.113546
# batch 16 d_loss : 0.152590
# batch 16 g_loss : 2.767862
# batch 17 d_loss : 0.287613
# batch 17 g_loss : 2.878442
# batch 18 d_loss : 0.193970
# batch 18 g_loss : 3.291529
# batch 19 d_loss : 0.137982
# batch 19 g_loss : 3.461986
# batch 20 d_loss : 0.138883
# batch 20 g_loss : 3.312639
# Epoch is 19
# Number of batches 21
# batch 0 d_loss : 0.295077
# batch 0 g_loss : 2.909335
# batch 1 d_loss : 0.131905
# batch 1 g_loss : 2.975933
# batch 2 d_loss : 0.272942
# batch 2 g_loss : 3.294720
# batch 3 d_loss : 0.251651
# batch 3 g_loss : 2.952233
# batch 4 d_loss : 0.203341
# batch 4 g_loss : 3.308015
# batch 5 d_loss : 0.087467
# batch 5 g_loss : 3.345627
# batch 6 d_loss : 0.150518
# batch 6 g_loss : 3.057816
# batch 7 d_loss : 0.354374
# batch 7 g_loss : 3.234227
# batch 8 d_loss : 0.378493
# batch 8 g_loss : 2.742417
# batch 9 d_loss : 0.173457
# batch 9 g_loss : 2.861617
# batch 10 d_loss : 0.127169
# batch 10 g_loss : 2.851148
# batch 11 d_loss : 0.165449
# batch 11 g_loss : 3.172038
# batch 12 d_loss : 0.170681
# batch 12 g_loss : 2.717262
# batch 13 d_loss : 0.239857
# batch 13 g_loss : 2.784181
# batch 14 d_loss : 0.101699
# batch 14 g_loss : 2.627642
# batch 15 d_loss : 0.090924
# batch 15 g_loss : 2.943191
# batch 16 d_loss : 0.117791
# batch 16 g_loss : 3.312674
# batch 17 d_loss : 0.127694
# batch 17 g_loss : 2.820172
# batch 18 d_loss : 0.115461
# batch 18 g_loss : 2.927640
# batch 19 d_loss : 0.133294
# batch 19 g_loss : 3.346818
# batch 20 d_loss : 0.099964
# batch 20 g_loss : 2.427628
# Epoch is 20
# Number of batches 21
# batch 0 d_loss : 0.213906
# batch 0 g_loss : 2.941392
# batch 1 d_loss : 0.121901
# batch 1 g_loss : 2.926540
# batch 2 d_loss : 0.183435
# batch 2 g_loss : 2.907076
# batch 3 d_loss : 0.256428
# batch 3 g_loss : 2.811160
# batch 4 d_loss : 0.098375
# batch 4 g_loss : 2.877298
# batch 5 d_loss : 0.125334
# batch 5 g_loss : 2.839858
# batch 6 d_loss : 0.181019
# batch 6 g_loss : 2.884198
# batch 7 d_loss : 0.262606
# batch 7 g_loss : 2.460594
# batch 8 d_loss : 0.237201
# batch 8 g_loss : 3.055430
# batch 9 d_loss : 0.167245
# batch 9 g_loss : 2.809457
# batch 10 d_loss : 0.145817
# batch 10 g_loss : 2.805779
# batch 11 d_loss : 0.156204
# batch 11 g_loss : 2.910152
# batch 12 d_loss : 0.142078
# batch 12 g_loss : 2.710463
# batch 13 d_loss : 0.212093
# batch 13 g_loss : 3.001238
# batch 14 d_loss : 0.103220
# batch 14 g_loss : 2.547413
# batch 15 d_loss : 0.124393
# batch 15 g_loss : 2.683005
# batch 16 d_loss : 0.097448
# batch 16 g_loss : 2.111684
# batch 17 d_loss : 0.132414
# batch 17 g_loss : 2.630862
# batch 18 d_loss : 0.073974
# batch 18 g_loss : 2.690451
# batch 19 d_loss : 0.096497
# batch 19 g_loss : 2.846146
# batch 20 d_loss : 0.076549
# batch 20 g_loss : 2.506782
# Epoch is 21
# Number of batches 21
# batch 0 d_loss : 0.164383
# batch 0 g_loss : 2.726026
# batch 1 d_loss : 0.083279
# batch 1 g_loss : 2.541383
# batch 2 d_loss : 0.204882
# batch 2 g_loss : 3.141346
# batch 3 d_loss : 0.156117
# batch 3 g_loss : 2.643883
# batch 4 d_loss : 0.136154
# batch 4 g_loss : 2.601490
# batch 5 d_loss : 0.105014
# batch 5 g_loss : 2.514380
# batch 6 d_loss : 0.132444
# batch 6 g_loss : 2.998564
# batch 7 d_loss : 0.152276
# batch 7 g_loss : 2.266805
# batch 8 d_loss : 0.180710
# batch 8 g_loss : 2.148081
# batch 9 d_loss : 0.161848
# batch 9 g_loss : 3.036784
# batch 10 d_loss : 0.126830
# batch 10 g_loss : 2.349583
# batch 11 d_loss : 0.187480
# batch 11 g_loss : 2.737910
# batch 12 d_loss : 0.130521
# batch 12 g_loss : 1.895429
# batch 13 d_loss : 0.262095
# batch 13 g_loss : 1.926732
# batch 14 d_loss : 0.064954
# batch 14 g_loss : 1.759877
# batch 15 d_loss : 0.052325
# batch 15 g_loss : 2.308745
# batch 16 d_loss : 0.111801
# batch 16 g_loss : 2.250788
# batch 17 d_loss : 0.106684
# batch 17 g_loss : 2.219728
# batch 18 d_loss : 0.078567
# batch 18 g_loss : 2.795258
# batch 19 d_loss : 0.086028
# batch 19 g_loss : 3.247577
# batch 20 d_loss : 0.080594
# batch 20 g_loss : 2.591826
# Epoch is 22
# Number of batches 21
# batch 0 d_loss : 0.211883
# batch 0 g_loss : 2.242903
# batch 1 d_loss : 0.075835
# batch 1 g_loss : 2.311716
# batch 2 d_loss : 0.232151
# batch 2 g_loss : 2.049137
# batch 3 d_loss : 0.154910
# batch 3 g_loss : 2.651480
# batch 4 d_loss : 0.094079
# batch 4 g_loss : 2.599940
# batch 5 d_loss : 0.067444
# batch 5 g_loss : 2.257005
# batch 6 d_loss : 0.069108
# batch 6 g_loss : 2.583817
# batch 7 d_loss : 0.132747
# batch 7 g_loss : 2.733444
# batch 8 d_loss : 0.174468
# batch 8 g_loss : 2.263510
# batch 9 d_loss : 0.127708
# batch 9 g_loss : 2.052630
# batch 10 d_loss : 0.104572
# batch 10 g_loss : 2.376216
# batch 11 d_loss : 0.182286
# batch 11 g_loss : 2.534702
# batch 12 d_loss : 0.162581
# batch 12 g_loss : 2.631543
# batch 13 d_loss : 0.170288
# batch 13 g_loss : 2.605630
# batch 14 d_loss : 0.075514
# batch 14 g_loss : 1.960773
# batch 15 d_loss : 0.077980
# batch 15 g_loss : 2.355548
# batch 16 d_loss : 0.088456
# batch 16 g_loss : 2.429697
# batch 17 d_loss : 0.073591
# batch 17 g_loss : 2.420255
# batch 18 d_loss : 0.091798
# batch 18 g_loss : 2.758535
# batch 19 d_loss : 0.073773
# batch 19 g_loss : 2.483197
# batch 20 d_loss : 0.115916
# batch 20 g_loss : 2.042693
# Epoch is 23
# Number of batches 21
# batch 0 d_loss : 0.215170
# batch 0 g_loss : 2.116647
# batch 1 d_loss : 0.072930
# batch 1 g_loss : 1.985255
# batch 2 d_loss : 0.234675
# batch 2 g_loss : 2.013453
# batch 3 d_loss : 0.200960
# batch 3 g_loss : 2.309453
# batch 4 d_loss : 0.080938
# batch 4 g_loss : 2.512326
# batch 5 d_loss : 0.051814
# batch 5 g_loss : 2.138163
# batch 6 d_loss : 0.076876
# batch 6 g_loss : 1.798369
# batch 7 d_loss : 0.054639
# batch 7 g_loss : 1.939801
# batch 8 d_loss : 0.092162
# batch 8 g_loss : 2.169864
# batch 9 d_loss : 0.182823
# batch 9 g_loss : 2.174022
# batch 10 d_loss : 0.219915
# batch 10 g_loss : 1.883361
# batch 11 d_loss : 0.200150
# batch 11 g_loss : 2.038620
# batch 12 d_loss : 0.120986
# batch 12 g_loss : 2.326017
# batch 13 d_loss : 0.127976
# batch 13 g_loss : 2.068381
# batch 14 d_loss : 0.052828
# batch 14 g_loss : 2.952559
# batch 15 d_loss : 0.062382
# batch 15 g_loss : 1.612328
# batch 16 d_loss : 0.085427
# batch 16 g_loss : 2.430189
# batch 17 d_loss : 0.115191
# batch 17 g_loss : 1.547562
# batch 18 d_loss : 0.093403
# batch 18 g_loss : 2.429810
# batch 19 d_loss : 0.098148
# batch 19 g_loss : 1.939613
# batch 20 d_loss : 0.059323
# batch 20 g_loss : 2.198797
# Epoch is 24
# Number of batches 21
# batch 0 d_loss : 0.236487
# batch 0 g_loss : 2.299232
# batch 1 d_loss : 0.087639
# batch 1 g_loss : 2.044186
# batch 2 d_loss : 0.252327
# batch 2 g_loss : 2.075373
# batch 3 d_loss : 0.167642
# batch 3 g_loss : 2.240415
# batch 4 d_loss : 0.084432
# batch 4 g_loss : 2.273252
# batch 5 d_loss : 0.082916
# batch 5 g_loss : 2.092399
# batch 6 d_loss : 0.138841
# batch 6 g_loss : 2.709644
# batch 7 d_loss : 0.067917
# batch 7 g_loss : 1.878767
# batch 8 d_loss : 0.093645
# batch 8 g_loss : 2.592649
# batch 9 d_loss : 0.142262
# batch 9 g_loss : 1.775202
# batch 10 d_loss : 0.188639
# batch 10 g_loss : 2.210094
# batch 11 d_loss : 0.252840
# batch 11 g_loss : 1.499329
# batch 12 d_loss : 0.198742
# batch 12 g_loss : 2.446185
# batch 13 d_loss : 0.112167
# batch 13 g_loss : 2.463043
# batch 14 d_loss : 0.120023
# batch 14 g_loss : 1.875703
# batch 15 d_loss : 0.127183
# batch 15 g_loss : 1.774044
# batch 16 d_loss : 0.093043
# batch 16 g_loss : 2.222023
# batch 17 d_loss : 0.086054
# batch 17 g_loss : 2.034776
# batch 18 d_loss : 0.145051
# batch 18 g_loss : 2.266757
# batch 19 d_loss : 0.128478
# batch 19 g_loss : 2.311951
# batch 20 d_loss : 0.068789
# batch 20 g_loss : 2.145569
# Epoch is 25
# Number of batches 21
# batch 0 d_loss : 0.287052
# batch 0 g_loss : 2.493703
# batch 1 d_loss : 0.099445
# batch 1 g_loss : 1.811266
# batch 2 d_loss : 0.314776
# batch 2 g_loss : 1.899587
# batch 3 d_loss : 0.241372
# batch 3 g_loss : 2.469291
# batch 4 d_loss : 0.115693
# batch 4 g_loss : 1.259743
# batch 5 d_loss : 0.103184
# batch 5 g_loss : 2.048675
# batch 6 d_loss : 0.076839
# batch 6 g_loss : 1.461796
# batch 7 d_loss : 0.129980
# batch 7 g_loss : 2.154326
# batch 8 d_loss : 0.191483
# batch 8 g_loss : 2.001062
# batch 9 d_loss : 0.149257
# batch 9 g_loss : 1.778616
# batch 10 d_loss : 0.187910
# batch 10 g_loss : 2.391419
# batch 11 d_loss : 0.250505
# batch 11 g_loss : 2.159856
# batch 12 d_loss : 0.157373
# batch 12 g_loss : 2.009404
# batch 13 d_loss : 0.144860
# batch 13 g_loss : 2.116593
# batch 14 d_loss : 0.094429
# batch 14 g_loss : 1.989638
# batch 15 d_loss : 0.137293
# batch 15 g_loss : 1.926654
# batch 16 d_loss : 0.124861
# batch 16 g_loss : 2.480203
# batch 17 d_loss : 0.132692
# batch 17 g_loss : 2.240120
# batch 18 d_loss : 0.170613
# batch 18 g_loss : 2.170743
# batch 19 d_loss : 0.203073
# batch 19 g_loss : 2.578153
# batch 20 d_loss : 0.078836
# batch 20 g_loss : 2.123321
# Epoch is 26
# Number of batches 21
# batch 0 d_loss : 0.321077
# batch 0 g_loss : 2.396560
# batch 1 d_loss : 0.094501
# batch 1 g_loss : 1.770057
# batch 2 d_loss : 0.335978
# batch 2 g_loss : 2.098117
# batch 3 d_loss : 0.231508
# batch 3 g_loss : 1.932550
# batch 4 d_loss : 0.184574
# batch 4 g_loss : 1.732880
# batch 5 d_loss : 0.152350
# batch 5 g_loss : 2.262625
# batch 6 d_loss : 0.158831
# batch 6 g_loss : 2.488801
# batch 7 d_loss : 0.190574
# batch 7 g_loss : 2.025429
# batch 8 d_loss : 0.117296
# batch 8 g_loss : 2.951371
# batch 9 d_loss : 0.239572
# batch 9 g_loss : 2.333117
# batch 10 d_loss : 0.205196
# batch 10 g_loss : 2.429627
# batch 11 d_loss : 0.370783
# batch 11 g_loss : 2.425394
# batch 12 d_loss : 0.259844
# batch 12 g_loss : 2.664518
# batch 13 d_loss : 0.189829
# batch 13 g_loss : 2.254660
# batch 14 d_loss : 0.119537
# batch 14 g_loss : 1.668811
# batch 15 d_loss : 0.165422
# batch 15 g_loss : 1.559972
# batch 16 d_loss : 0.096266
# batch 16 g_loss : 2.192292
# batch 17 d_loss : 0.133938
# batch 17 g_loss : 1.989907
# batch 18 d_loss : 0.213555
# batch 18 g_loss : 1.746195
# batch 19 d_loss : 0.140714
# batch 19 g_loss : 1.719625
# batch 20 d_loss : 0.086412
# batch 20 g_loss : 2.736096
# Epoch is 27
# Number of batches 21
# batch 0 d_loss : 0.322705
# batch 0 g_loss : 2.351858
# batch 1 d_loss : 0.089553
# batch 1 g_loss : 1.966999
# batch 2 d_loss : 0.289546
# batch 2 g_loss : 2.318001
# batch 3 d_loss : 0.243818
# batch 3 g_loss : 2.089194
# batch 4 d_loss : 0.134620
# batch 4 g_loss : 2.397789
# batch 5 d_loss : 0.165363
# batch 5 g_loss : 2.136363
# batch 6 d_loss : 0.150630
# batch 6 g_loss : 1.869136
# batch 7 d_loss : 0.178554
# batch 7 g_loss : 1.911744
# batch 8 d_loss : 0.111621
# batch 8 g_loss : 2.040734
# batch 9 d_loss : 0.219236
# batch 9 g_loss : 1.526772
# batch 10 d_loss : 0.247809
# batch 10 g_loss : 2.473501
# batch 11 d_loss : 0.415551
# batch 11 g_loss : 1.993687
# batch 12 d_loss : 0.215474
# batch 12 g_loss : 1.605818
# batch 13 d_loss : 0.185295
# batch 13 g_loss : 1.883371
# batch 14 d_loss : 0.125286
# batch 14 g_loss : 2.336786
# batch 15 d_loss : 0.161245
# batch 15 g_loss : 2.429892
# batch 16 d_loss : 0.104777
# batch 16 g_loss : 2.411985
# batch 17 d_loss : 0.111970
# batch 17 g_loss : 1.806173
# batch 18 d_loss : 0.169804
# batch 18 g_loss : 2.420314
# batch 19 d_loss : 0.210612
# batch 19 g_loss : 1.911775
# batch 20 d_loss : 0.089701
# batch 20 g_loss : 2.663992
# Epoch is 28
# Number of batches 21
# batch 0 d_loss : 0.404116
# batch 0 g_loss : 1.940097
# batch 1 d_loss : 0.157250
# batch 1 g_loss : 2.641668
# batch 2 d_loss : 0.369748
# batch 2 g_loss : 1.995135
# batch 3 d_loss : 0.231545
# batch 3 g_loss : 2.358362
# batch 4 d_loss : 0.137006
# batch 4 g_loss : 1.938705
# batch 5 d_loss : 0.235581
# batch 5 g_loss : 2.694703
# batch 6 d_loss : 0.137287
# batch 6 g_loss : 2.492578
# batch 7 d_loss : 0.094362
# batch 7 g_loss : 1.797780
# batch 8 d_loss : 0.135005
# batch 8 g_loss : 2.040717
# batch 9 d_loss : 0.255431
# batch 9 g_loss : 1.479847
# batch 10 d_loss : 0.213985
# batch 10 g_loss : 2.597100
# batch 11 d_loss : 0.263653
# batch 11 g_loss : 1.830242
# batch 12 d_loss : 0.202894
# batch 12 g_loss : 2.543708
# batch 13 d_loss : 0.138130
# batch 13 g_loss : 2.555515
# batch 14 d_loss : 0.114756
# batch 14 g_loss : 1.700557
# batch 15 d_loss : 0.144039
# batch 15 g_loss : 2.608939
# batch 16 d_loss : 0.099484
# batch 16 g_loss : 2.180799
# batch 17 d_loss : 0.092807
# batch 17 g_loss : 2.102007
# batch 18 d_loss : 0.104039
# batch 18 g_loss : 2.255781
# batch 19 d_loss : 0.133798
# batch 19 g_loss : 2.674006
# batch 20 d_loss : 0.081096
# batch 20 g_loss : 2.902783
# Epoch is 29
# Number of batches 21
# batch 0 d_loss : 0.287160
# batch 0 g_loss : 2.633706
# batch 1 d_loss : 0.071384
# batch 1 g_loss : 1.960870
# batch 2 d_loss : 0.252204
# batch 2 g_loss : 2.244709
# batch 3 d_loss : 0.251613
# batch 3 g_loss : 2.143317
# batch 4 d_loss : 0.164761
# batch 4 g_loss : 1.822076
# batch 5 d_loss : 0.238356
# batch 5 g_loss : 2.494422
# batch 6 d_loss : 0.101031
# batch 6 g_loss : 2.442804
# batch 7 d_loss : 0.132979
# batch 7 g_loss : 1.733963
# batch 8 d_loss : 0.146895
# batch 8 g_loss : 2.103508
# batch 9 d_loss : 0.267755
# batch 9 g_loss : 2.177410
# batch 10 d_loss : 0.138162
# batch 10 g_loss : 1.973709
# batch 11 d_loss : 0.247146
# batch 11 g_loss : 2.425061
# batch 12 d_loss : 0.150436
# batch 12 g_loss : 2.273745
# batch 13 d_loss : 0.178806
# batch 13 g_loss : 2.271403
# batch 14 d_loss : 0.083120
# batch 14 g_loss : 1.844103
# batch 15 d_loss : 0.102734
# batch 15 g_loss : 2.202747
# batch 16 d_loss : 0.092458
# batch 16 g_loss : 1.918788
# batch 17 d_loss : 0.161156
# batch 17 g_loss : 1.631391
# batch 18 d_loss : 0.134411
# batch 18 g_loss : 2.590997
# batch 19 d_loss : 0.139104
# batch 19 g_loss : 3.219742
# batch 20 d_loss : 0.122116
# batch 20 g_loss : 2.687847
# Epoch is 30
# Number of batches 21
# batch 0 d_loss : 0.243280
# batch 0 g_loss : 2.761985
# batch 1 d_loss : 0.074743
# batch 1 g_loss : 2.530601
# batch 2 d_loss : 0.257722
# batch 2 g_loss : 2.073087
# batch 3 d_loss : 0.145381
# batch 3 g_loss : 2.191990
# batch 4 d_loss : 0.146850
# batch 4 g_loss : 2.851068
# batch 5 d_loss : 0.210091
# batch 5 g_loss : 1.973526
# batch 6 d_loss : 0.151814
# batch 6 g_loss : 2.097799
# batch 7 d_loss : 0.155891
# batch 7 g_loss : 2.220016
# batch 8 d_loss : 0.207029
# batch 8 g_loss : 2.067250
# batch 9 d_loss : 0.186087
# batch 9 g_loss : 2.112934
# batch 10 d_loss : 0.084533
# batch 10 g_loss : 2.002957
# batch 11 d_loss : 0.214987
# batch 11 g_loss : 2.011260
# batch 12 d_loss : 0.183969
# batch 12 g_loss : 2.265501
# batch 13 d_loss : 0.149629
# batch 13 g_loss : 2.076271
# batch 14 d_loss : 0.102058
# batch 14 g_loss : 1.792958
# batch 15 d_loss : 0.063640
# batch 15 g_loss : 2.410852
# batch 16 d_loss : 0.111377
# batch 16 g_loss : 2.231066
# batch 17 d_loss : 0.109932
# batch 17 g_loss : 1.729319
# batch 18 d_loss : 0.107932
# batch 18 g_loss : 2.395368
# batch 19 d_loss : 0.157667
# batch 19 g_loss : 2.181024
# batch 20 d_loss : 0.136344
# batch 20 g_loss : 2.070919
# Epoch is 31
# Number of batches 21
# batch 0 d_loss : 0.277863
# batch 0 g_loss : 2.952261
# batch 1 d_loss : 0.058999
# batch 1 g_loss : 2.723204
# batch 2 d_loss : 0.217965
# batch 2 g_loss : 2.237662
# batch 3 d_loss : 0.146493
# batch 3 g_loss : 2.356552
# batch 4 d_loss : 0.190638
# batch 4 g_loss : 1.987786
# batch 5 d_loss : 0.387301
# batch 5 g_loss : 2.568108
# batch 6 d_loss : 0.219397
# batch 6 g_loss : 2.433230
# batch 7 d_loss : 0.108719
# batch 7 g_loss : 2.371524
# batch 8 d_loss : 0.173754
# batch 8 g_loss : 3.121709
# batch 9 d_loss : 0.281277
# batch 9 g_loss : 2.553827
# batch 10 d_loss : 0.184707
# batch 10 g_loss : 2.007821
# batch 11 d_loss : 0.192655
# batch 11 g_loss : 1.980669
# batch 12 d_loss : 0.148925
# batch 12 g_loss : 2.425170
# batch 13 d_loss : 0.121047
# batch 13 g_loss : 2.717813
# batch 14 d_loss : 0.130466
# batch 14 g_loss : 1.680999
# batch 15 d_loss : 0.078436
# batch 15 g_loss : 2.836015
# batch 16 d_loss : 0.087474
# batch 16 g_loss : 2.244038
# batch 17 d_loss : 0.072854
# batch 17 g_loss : 2.727987
# batch 18 d_loss : 0.082768
# batch 18 g_loss : 2.114684
# batch 19 d_loss : 0.147703
# batch 19 g_loss : 2.593138
# batch 20 d_loss : 0.073966
# batch 20 g_loss : 2.852586
# Epoch is 32
# Number of batches 21
# batch 0 d_loss : 0.272244
# batch 0 g_loss : 2.136908
# batch 1 d_loss : 0.058730
# batch 1 g_loss : 2.205958
# batch 2 d_loss : 0.203747
# batch 2 g_loss : 2.939992
# batch 3 d_loss : 0.167917
# batch 3 g_loss : 2.376372
# batch 4 d_loss : 0.164128
# batch 4 g_loss : 3.107853
# batch 5 d_loss : 0.341634
# batch 5 g_loss : 2.519966
# batch 6 d_loss : 0.260923
# batch 6 g_loss : 1.872910
# batch 7 d_loss : 0.139698
# batch 7 g_loss : 2.345404
# batch 8 d_loss : 0.076146
# batch 8 g_loss : 1.790494
# batch 9 d_loss : 0.169638
# batch 9 g_loss : 2.683149
# batch 10 d_loss : 0.194068
# batch 10 g_loss : 1.533511
# batch 11 d_loss : 0.254089
# batch 11 g_loss : 1.799812
# batch 12 d_loss : 0.133612
# batch 12 g_loss : 2.380400
# batch 13 d_loss : 0.162522
# batch 13 g_loss : 2.017028
# batch 14 d_loss : 0.142377
# batch 14 g_loss : 2.608068
# batch 15 d_loss : 0.190557
# batch 15 g_loss : 1.949707
# batch 16 d_loss : 0.146581
# batch 16 g_loss : 2.981568
# batch 17 d_loss : 0.197228
# batch 17 g_loss : 2.058289
# batch 18 d_loss : 0.077787
# batch 18 g_loss : 2.491151
# batch 19 d_loss : 0.185068
# batch 19 g_loss : 2.733362
# batch 20 d_loss : 0.128215
# batch 20 g_loss : 2.382714
# Epoch is 33
# Number of batches 21
# batch 0 d_loss : 0.376846
# batch 0 g_loss : 2.690109
# batch 1 d_loss : 0.068878
# batch 1 g_loss : 2.625280
# batch 2 d_loss : 0.310913
# batch 2 g_loss : 3.035621
# batch 3 d_loss : 0.162014
# batch 3 g_loss : 2.385896
# batch 4 d_loss : 0.195942
# batch 4 g_loss : 2.147811
# batch 5 d_loss : 0.293126
# batch 5 g_loss : 2.434653
# batch 6 d_loss : 0.250232
# batch 6 g_loss : 2.879407
# batch 7 d_loss : 0.192976
# batch 7 g_loss : 2.049077
# batch 8 d_loss : 0.132727
# batch 8 g_loss : 2.029837
# batch 9 d_loss : 0.232608
# batch 9 g_loss : 1.832386
# batch 10 d_loss : 0.118504
# batch 10 g_loss : 1.887967
# batch 11 d_loss : 0.234427
# batch 11 g_loss : 2.373431
# batch 12 d_loss : 0.207971
# batch 12 g_loss : 2.356648
# batch 13 d_loss : 0.263811
# batch 13 g_loss : 3.097237
# batch 14 d_loss : 0.107746
# batch 14 g_loss : 2.170308
# batch 15 d_loss : 0.101789
# batch 15 g_loss : 2.572940
# batch 16 d_loss : 0.094740
# batch 16 g_loss : 2.536330
# batch 17 d_loss : 0.184589
# batch 17 g_loss : 2.130529
# batch 18 d_loss : 0.075604
# batch 18 g_loss : 2.811621
# batch 19 d_loss : 0.160394
# batch 19 g_loss : 2.179610
# batch 20 d_loss : 0.117164
# batch 20 g_loss : 2.729136
# Epoch is 34
# Number of batches 21
# batch 0 d_loss : 0.374947
# batch 0 g_loss : 2.054163
# batch 1 d_loss : 0.072203
# batch 1 g_loss : 2.421281
# batch 2 d_loss : 0.302549
# batch 2 g_loss : 2.494692
# batch 3 d_loss : 0.161124
# batch 3 g_loss : 2.359937
# batch 4 d_loss : 0.198631
# batch 4 g_loss : 2.078693
# batch 5 d_loss : 0.260785
# batch 5 g_loss : 2.323821
# batch 6 d_loss : 0.175340
# batch 6 g_loss : 2.002198
# batch 7 d_loss : 0.146912
# batch 7 g_loss : 1.991877
# batch 8 d_loss : 0.174614
# batch 8 g_loss : 2.279055
# batch 9 d_loss : 0.131932
# batch 9 g_loss : 1.816649
# batch 10 d_loss : 0.290077
# batch 10 g_loss : 2.367595
# batch 11 d_loss : 0.281974
# batch 11 g_loss : 1.357413
# batch 12 d_loss : 0.210602
# batch 12 g_loss : 1.945792
# batch 13 d_loss : 0.178027
# batch 13 g_loss : 1.495226
# batch 14 d_loss : 0.097929
# batch 14 g_loss : 2.676056
# batch 15 d_loss : 0.127593
# batch 15 g_loss : 2.475043
# batch 16 d_loss : 0.066404
# batch 16 g_loss : 3.218021
# batch 17 d_loss : 0.114628
# batch 17 g_loss : 2.461011
# batch 18 d_loss : 0.105035
# batch 18 g_loss : 2.286945
# batch 19 d_loss : 0.148706
# batch 19 g_loss : 2.536818
# batch 20 d_loss : 0.105355
# batch 20 g_loss : 2.203803
# Epoch is 35
# Number of batches 21
# batch 0 d_loss : 0.292372
# batch 0 g_loss : 1.952416
# batch 1 d_loss : 0.039366
# batch 1 g_loss : 2.235638
# batch 2 d_loss : 0.294929
# batch 2 g_loss : 3.211742
# batch 3 d_loss : 0.147595
# batch 3 g_loss : 2.550169
# batch 4 d_loss : 0.192766
# batch 4 g_loss : 1.942647
# batch 5 d_loss : 0.299780
# batch 5 g_loss : 3.155582
# batch 6 d_loss : 0.164036
# batch 6 g_loss : 1.750258
# batch 7 d_loss : 0.446957
# batch 7 g_loss : 2.133996
# batch 8 d_loss : 0.162647
# batch 8 g_loss : 1.740277
# batch 9 d_loss : 0.152576
# batch 9 g_loss : 2.380037
# batch 10 d_loss : 0.168544
# batch 10 g_loss : 2.507427
# batch 11 d_loss : 0.217809
# batch 11 g_loss : 2.259598
# batch 12 d_loss : 0.218541
# batch 12 g_loss : 2.424806
# batch 13 d_loss : 0.134795
# batch 13 g_loss : 2.485070
# batch 14 d_loss : 0.068472
# batch 14 g_loss : 2.351005
# batch 15 d_loss : 0.092787
# batch 15 g_loss : 2.228376
# batch 16 d_loss : 0.052666
# batch 16 g_loss : 2.055835
# batch 17 d_loss : 0.115459
# batch 17 g_loss : 1.832267
# batch 18 d_loss : 0.128846
# batch 18 g_loss : 2.943428
# batch 19 d_loss : 0.138254
# batch 19 g_loss : 3.274588
# batch 20 d_loss : 0.104658
# batch 20 g_loss : 2.613083
# Epoch is 36
# Number of batches 21
# batch 0 d_loss : 0.254215
# batch 0 g_loss : 2.302601
# batch 1 d_loss : 0.047602
# batch 1 g_loss : 2.201018
# batch 2 d_loss : 0.279822
# batch 2 g_loss : 2.426237
# batch 3 d_loss : 0.131265
# batch 3 g_loss : 1.979366
# batch 4 d_loss : 0.193815
# batch 4 g_loss : 1.450736
# batch 5 d_loss : 0.252733
# batch 5 g_loss : 2.169759
# batch 6 d_loss : 0.198566
# batch 6 g_loss : 2.656620
# batch 7 d_loss : 0.074610
# batch 7 g_loss : 2.241168
# batch 8 d_loss : 0.083027
# batch 8 g_loss : 1.663472
# batch 9 d_loss : 0.116924
# batch 9 g_loss : 2.716230
# batch 10 d_loss : 0.146196
# batch 10 g_loss : 2.070404
# batch 11 d_loss : 0.202434
# batch 11 g_loss : 2.158445
# batch 12 d_loss : 0.199852
# batch 12 g_loss : 2.441461
# batch 13 d_loss : 0.261617
# batch 13 g_loss : 2.587444
# batch 14 d_loss : 0.160329
# batch 14 g_loss : 2.691130
# batch 15 d_loss : 0.085730
# batch 15 g_loss : 3.547832
# batch 16 d_loss : 0.107439
# batch 16 g_loss : 2.301810
# batch 17 d_loss : 0.147204
# batch 17 g_loss : 2.521845
# batch 18 d_loss : 0.099602
# batch 18 g_loss : 3.189697
# batch 19 d_loss : 0.160893
# batch 19 g_loss : 2.599676
# batch 20 d_loss : 0.090563
# batch 20 g_loss : 2.650466
# Epoch is 37
# Number of batches 21
# batch 0 d_loss : 0.266874
# batch 0 g_loss : 2.914581
# batch 1 d_loss : 0.079802
# batch 1 g_loss : 2.990381
# batch 2 d_loss : 0.294327
# batch 2 g_loss : 2.971912
# batch 3 d_loss : 0.181879
# batch 3 g_loss : 2.915786
# batch 4 d_loss : 0.232381
# batch 4 g_loss : 2.910246
# batch 5 d_loss : 0.319983
# batch 5 g_loss : 3.195833
# batch 6 d_loss : 0.208767
# batch 6 g_loss : 2.215850
# batch 7 d_loss : 0.055260
# batch 7 g_loss : 2.235440
# batch 8 d_loss : 0.255167
# batch 8 g_loss : 1.945701
# batch 9 d_loss : 0.170444
# batch 9 g_loss : 2.294975
# batch 10 d_loss : 0.282126
# batch 10 g_loss : 2.342745
# batch 11 d_loss : 0.259502
# batch 11 g_loss : 2.356832
# batch 12 d_loss : 0.131345
# batch 12 g_loss : 3.250482
# batch 13 d_loss : 0.192203
# batch 13 g_loss : 2.481328
# batch 14 d_loss : 0.085066
# batch 14 g_loss : 2.209975
# batch 15 d_loss : 0.095388
# batch 15 g_loss : 2.786240
# batch 16 d_loss : 0.042564
# batch 16 g_loss : 2.975548
# batch 17 d_loss : 0.060308
# batch 17 g_loss : 2.484945
# batch 18 d_loss : 0.168024
# batch 18 g_loss : 2.707463
# batch 19 d_loss : 0.117445
# batch 19 g_loss : 2.821261
# batch 20 d_loss : 0.124512
# batch 20 g_loss : 2.924053
# Epoch is 38
# Number of batches 21
# batch 0 d_loss : 0.277746
# batch 0 g_loss : 2.845319
# batch 1 d_loss : 0.049885
# batch 1 g_loss : 3.440125
# batch 2 d_loss : 0.331104
# batch 2 g_loss : 2.501542
# batch 3 d_loss : 0.199078
# batch 3 g_loss : 2.953403
# batch 4 d_loss : 0.255106
# batch 4 g_loss : 2.811329
# batch 5 d_loss : 0.305369
# batch 5 g_loss : 2.060147
# batch 6 d_loss : 0.205814
# batch 6 g_loss : 2.416143
# batch 7 d_loss : 0.113003
# batch 7 g_loss : 2.785453
# batch 8 d_loss : 0.185529
# batch 8 g_loss : 2.183668
# batch 9 d_loss : 0.179496
# batch 9 g_loss : 2.414377
# batch 10 d_loss : 0.170676
# batch 10 g_loss : 2.364303
# batch 11 d_loss : 0.226697
# batch 11 g_loss : 2.239000
# batch 12 d_loss : 0.155981
# batch 12 g_loss : 2.378397
# batch 13 d_loss : 0.076024
# batch 13 g_loss : 2.838666
# batch 14 d_loss : 0.099713
# batch 14 g_loss : 2.123224
# batch 15 d_loss : 0.123406
# batch 15 g_loss : 2.339385
# batch 16 d_loss : 0.097818
# batch 16 g_loss : 1.874704
# batch 17 d_loss : 0.051040
# batch 17 g_loss : 2.568906
# batch 18 d_loss : 0.081092
# batch 18 g_loss : 2.183055
# batch 19 d_loss : 0.109975
# batch 19 g_loss : 2.414119
# batch 20 d_loss : 0.073377
# batch 20 g_loss : 2.536915
# Epoch is 39
# Number of batches 21
# batch 0 d_loss : 0.187869
# batch 0 g_loss : 3.178141
# batch 1 d_loss : 0.143208
# batch 1 g_loss : 2.538045
# batch 2 d_loss : 0.295367
# batch 2 g_loss : 2.889587
# batch 3 d_loss : 0.143003
# batch 3 g_loss : 2.251749
# batch 4 d_loss : 0.318360
# batch 4 g_loss : 3.227269
# batch 5 d_loss : 0.236425
# batch 5 g_loss : 2.823075
# batch 6 d_loss : 0.194052
# batch 6 g_loss : 2.238664
# batch 7 d_loss : 0.127057
# batch 7 g_loss : 2.244334
# batch 8 d_loss : 0.114319
# batch 8 g_loss : 2.431529
# batch 9 d_loss : 0.240464
# batch 9 g_loss : 2.802857
# batch 10 d_loss : 0.147200
# batch 10 g_loss : 2.535395
# batch 11 d_loss : 0.257929
# batch 11 g_loss : 2.337884
# batch 12 d_loss : 0.217067
# batch 12 g_loss : 1.959802
# batch 13 d_loss : 0.090447
# batch 13 g_loss : 2.597162
# batch 14 d_loss : 0.088066
# batch 14 g_loss : 2.832261
# batch 15 d_loss : 0.095610
# batch 15 g_loss : 2.985964
# batch 16 d_loss : 0.091441
# batch 16 g_loss : 3.170108
# batch 17 d_loss : 0.097950
# batch 17 g_loss : 2.338715
# batch 18 d_loss : 0.085179
# batch 18 g_loss : 2.406960
# batch 19 d_loss : 0.096954
# batch 19 g_loss : 1.937461
# batch 20 d_loss : 0.082102
# batch 20 g_loss : 2.106811

# %%
generate(1)
# Out:
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=512, input_dim=100)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Nidhi\Anaconda3.5\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (5, 5), padding="same")`
#   del sys.path[0]
# 1/1 [==============================] - 2s 2s/step
# (1, 1, 128, 128)
